# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPRegressor,MLPClassifier
from sklearn.model_selection import train_test_split

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in d:\my_flask_app\venv\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in d:\my_flask_app\venv\lib\site-packages (from pandas_datareader) (5.2.2)
# Requirement already satisfied: pandas>=0.23 in d:\my_flask_app\venv\lib\site-packages (from pandas_datareader) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in d:\my_flask_app\venv\lib\site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\my_flask_app\venv\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\my_flask_app\venv\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\my_flask_app\venv\lib\site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\my_flask_app\venv\lib\site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\my_flask_app\venv\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\my_flask_app\venv\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\my_flask_app\venv\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my_flask_app\venv\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in d:\my_flask_app\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)

# %%
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# Requirement already satisfied: requests in d:\my_flask_app\venv\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\my_flask_app\venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\my_flask_app\venv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\my_flask_app\venv\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my_flask_app\venv\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: html5lib in d:\my_flask_app\venv\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in d:\my_flask_app\venv\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in d:\my_flask_app\venv\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: bs4 in d:\my_flask_app\venv\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\my_flask_app\venv\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in d:\my_flask_app\venv\lib\site-packages (from beautifulsoup4->bs4) (2.5)

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in d:\my_flask_app\venv\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in d:\my_flask_app\venv\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in d:\my_flask_app\venv\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in d:\my_flask_app\venv\lib\site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\my_flask_app\venv\lib\site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\my_flask_app\venv\lib\site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\my_flask_app\venv\lib\site-packages (from requests->vaderSentiment) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\my_flask_app\venv\lib\site-packages (from requests->vaderSentiment) (2024.2.2)

# %%
#mint Web scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def getLiveUpdates():
    headers = {
        "User-Agent":
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36"
    }
    try:
        response = requests.get(
            "https://www.livemint.com/market/live-blog/reliance-power-share-price-today-latest-live-updates-on-23-may-2024-11716431773983.html", headers=headers
        )
        response.raise_for_status()  # Raise an error for bad status codes
        soup = BeautifulSoup(response.content, "html.parser")

        # Extracting the title of the webpage
        title_elem = soup.find("h2", class_="liveTitle")
        title = title_elem.get_text(strip=True) if title_elem else "No Title Available"
        print("Title:", title)
        print("="*50)

        live_updates = []

        for div in soup.find_all("div", class_="liveSec"):
            timestamp_elem = div.find("span", class_="timeStamp")
            content_elem = div.find("p")

            Date = timestamp_elem.get_text(strip=True) if timestamp_elem else "No Timestamp Available"
            content = content_elem.get_text(strip=True) if content_elem else "No Content Available"

            live_updates.append(
                {
                    "Title": title,
                    "Date": Date,  # Changed "Timestamp" to "Date"
                    "Content": content,
                }
            )

        for update in live_updates:
            print("Title:", update["Title"])
            print("Date:", update["Date"])  # Changed "Timestamp" to "Date"
            print("Content:", update["Content"])
            print("="*50)  # Separating each live update with a line

        # Save data to CSV
        save_to_csv(live_updates)

    except requests.RequestException as e:
        print("Error fetching data:", e)


def save_to_csv(live_updates):
    """
    Save live updates to CSV file.

    Parameters:
    - live_updates (list of dict): List containing dictionaries with live update data.
    """
    try:
        # Read the existing CSV file if it exists, otherwise create an empty DataFrame
        try:
            combined_df = pd.read_csv('live_updates_updated_2new.csv')
        except FileNotFoundError:
            combined_df = pd.DataFrame()

        # Convert the live updates to a DataFrame
        new_df = pd.DataFrame(live_updates)

        # Check if the DataFrame is empty
        if combined_df.empty:
            combined_df = new_df
        else:
            # Check for duplicate entries based on content
            new_content = set(new_df['Content'])
            existing_content = set(combined_df['Content'])
            unique_content = new_content - existing_content

            # Append only new unique entries to the existing DataFrame
            if unique_content:
                new_unique_entries = new_df[new_df['Content'].isin(unique_content)]
                combined_df = pd.concat([combined_df, new_unique_entries], ignore_index=True)
                print("New unique entries added to live_updates_updated_2new.csv")
            else:
                print("No new unique entries to add")

        # Save the updated DataFrame to a CSV file
        combined_df.to_csv('live_updates_updated_2new.csv', index=False)

    except Exception as e:
        print("Error:", e)

# Run the function to scrape live updates and save them to CSV
getLiveUpdates()

# %%
# manually news entries









import pandas as pd

def save_to_csv(live_updates, filename):
    """
    Save live updates to CSV file.

    Parameters:
    - live_updates (list of dict): List containing dictionaries with live update data.
    - filename (str): Name of the CSV file to save.
    """
    try:
        # Read the existing CSV file if it exists, otherwise create an empty DataFrame
        try:
            combined_df = pd.read_csv(filename)
        except FileNotFoundError:
            combined_df = pd.DataFrame()

        # Convert the live updates to a DataFrame
        new_df = pd.DataFrame(live_updates)

        # Check if the DataFrame is empty
        if combined_df.empty:
            combined_df = new_df
        else:
            # Check for duplicate entries based on both content and title
            new_unique_entries = []
            for index, row in new_df.iterrows():
                if (row['Title'] not in combined_df['Title'].values) and (row['Content'] not in combined_df['Content'].values):
                    new_unique_entries.append(row)

            if new_unique_entries:
                combined_df = pd.concat([combined_df, pd.DataFrame(new_unique_entries)], ignore_index=True)
                print("New unique entries added to", filename)
                print("Entry is entered into the dataset.")
            else:
                print("No new unique entries to add")
                print("Entry is not entered into the dataset.")

        # Save the updated DataFrame to a CSV file
        combined_df.to_csv(filename, index=False)

    except Exception as e:
        print("Error:", e)


def manually_set_live_updates():
    """
    Manually set Title, Date, and Content.
    """
    title = '''
Jsw Steel Outlook for the Week (May 20, 2024 – May 24, 2024)
    '''
    date = " 20 May 2024, 08:05:58 PM IST "
    content = '''

Reliance Power Share Price Today Live: Reliance Power's stock price remains unchanged at ₹26.14 today, showing a 0.00% increase. Over the past year, Reliance Power shares have surged by 129.39% to reach ₹26.14. In contrast, the Nifty index has risen by 23.61% to 22502.00 during the same one-year period.

    '''

    live_updates = [
        {
            "Title": title,
            "Date": date,
            "Content": content
        }
    ]

    # Save data to CSV with the new filename
    save_to_csv(live_updates, 'live_updates_updated_2new.csv')

# Run the function to manually set live updates and save them to CSV
manually_set_live_updates()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, timedelta
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import joblib
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Load news data
news_df = pd.read_csv('live_updates_updated_2new.csv')
print("News data loaded successfully")
print(news_df.head())
# Out:
# News data loaded successfully
#                                                Title         Date  \
# 0  Reliance Power share price update : Shareholdi...  09 May 2024
# 1  Reliance Power share price update : Shareholdi...  09 May 2024
# 2  Reliance Power share price update : Shareholdi...  09 May 2024
# 3  Reliance Power share price update : Shareholdi...  09 May 2024
# 4  Reliance Power share price update : Shareholdi...  09 May 2024
#
#                                              Content
# 0  Reliance Power has a 2.67% MF holding & 7.89% ...
# 1  Reliance Power's Return on Equity (ROE) in the...
# 2  Reliance Power has experienced a significant d...
# 3  Today, Reliance Power's stock price dropped by...
# 4  Reliance Power stock reached a low of₹24.55 an...

# %%
# Function to parse date and handle timezone warnings
def parse_date(date_str):
    try:
        return pd.to_datetime(date_str, errors='coerce')
    except Exception as e:
        print(f"Error parsing date: {e}")
        return pd.NaT

# Apply the date parsing function
news_df['Date'] = news_df['Date'].apply(parse_date)

# Drop rows with invalid dates
news_df = news_df.dropna(subset=['Date'])

print("Date parsing and cleaning done")
print(news_df.head())
# Out:
# Date parsing and cleaning done
#                                                Title       Date  \
# 0  Reliance Power share price update : Shareholdi... 2024-05-09
# 1  Reliance Power share price update : Shareholdi... 2024-05-09
# 2  Reliance Power share price update : Shareholdi... 2024-05-09
# 3  Reliance Power share price update : Shareholdi... 2024-05-09
# 4  Reliance Power share price update : Shareholdi... 2024-05-09
#
#                                              Content
# 0  Reliance Power has a 2.67% MF holding & 7.89% ...
# 1  Reliance Power's Return on Equity (ROE) in the...
# 2  Reliance Power has experienced a significant d...
# 3  Today, Reliance Power's stock price dropped by...
# 4  Reliance Power stock reached a low of₹24.55 an...
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 06:08:29 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 05:37:41 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 03:54:36 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 03:20:58 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 02:50:10 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 02:41:07 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 02:00:58 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 01:52:38 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 01:35:57 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 01:07:40 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 12:52:21 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 12:34:50 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 12:23:00 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 11:50:27 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 11:35:05 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 11:21:03 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 11:12:57 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 10:53:24 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 10:38:59 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 09:53:36 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 09:36:17 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 09:22:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 08:16:07 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 08:00:52 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 07:32:59 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "10 May 2024, 07:02:31 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 07:37:23 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 07:03:51 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 06:00:08 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 05:37:08 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 03:54:50 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 03:53:01 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 03:21:07 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 02:50:09 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 02:34:31 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 02:08:53 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 01:55:27 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 01:34:29 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 01:09:32 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 12:56:22 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 12:33:11 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 12:15:57 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 11:47:12 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 11:34:29 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 11:30:05 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 11:18:42 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 10:49:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 10:34:07 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 10:00:06 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 09:41:29 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 09:22:49 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 08:23:09 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "13 May 2024, 08:08:02 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 08:04:52 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 07:40:45 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 07:01:39 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 06:06:03 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 05:37:09 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 03:55:27 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 03:52:27 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 03:14:36 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 02:55:34 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 02:54:40 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 02:37:08 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 02:05:56 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 01:47:12 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 01:37:13 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 01:03:56 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 12:45:46 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 12:38:27 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 12:24:24 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 12:18:43 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 11:51:29 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 11:33:08 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 11:20:57 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 11:10:47 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 10:52:03 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 10:39:35 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 09:56:28 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 09:31:32 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 09:17:10 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 08:48:17 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 08:16:07 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "15 May 2024, 08:05:35 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 06:06:04 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 05:35:47 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 03:52:39 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 03:48:34 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 03:19:42 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 02:53:38 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 02:42:51 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 02:02:27 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 01:51:33 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 01:41:32 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 01:00:46 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 12:47:55 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 12:33:49 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 12:15:11 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 11:54:06 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 11:42:02 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 11:30:59 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 11:15:21 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 10:50:31 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 10:34:39 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 09:54:31 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 09:40:56 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 09:20:00 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 08:19:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 08:05:50 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 07:30:13 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "16 May 2024, 07:08:38 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "17 May 2024, 09:58:43 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "17 May 2024, 09:37:29 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "17 May 2024, 09:22:46 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "17 May 2024, 08:22:00 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# ...
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 02:50:50 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 02:42:05 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 02:09:28 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 01:45:49 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 01:37:17 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 01:07:00 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 12:48:41 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 12:42:01 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 12:18:46 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 11:51:16 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 11:33:03 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 11:28:04 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 11:19:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 10:47:56 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 10:34:40 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 09:53:40 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 09:38:06 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 09:24:57 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 08:17:43 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "22 May 2024, 08:03:45 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 02:45:54 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 02:41:19 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 02:01:33 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 01:53:35 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 01:38:35 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 01:00:03 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 12:53:23 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 12:39:50 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 12:20:14 PM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 11:53:28 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 11:35:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 11:23:38 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 11:10:51 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 10:50:29 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 10:35:47 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 09:52:16 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 09:30:24 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 09:21:36 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\4166782687.py:4: FutureWarning: Parsed string "23 May 2024, 08:06:18 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   return pd.to_datetime(date_str, errors='coerce')

# %%
# Initialize sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment score
def get_sentiment(text):
    try:
        sentiment = analyzer.polarity_scores(text)
        return sentiment['compound']
    except Exception as e:
        print(f"Error analyzing sentiment: {e}")
        return 0

# Apply sentiment analysis to the Content column
news_df['Sentiment'] = news_df['Content'].apply(get_sentiment)

print("Sentiment analysis done")
print(news_df.head())

# Aggregate sentiment scores over 7-day windows
news_df.set_index('Date', inplace=True)
news_df = news_df.resample('7D').mean(numeric_only=True).reset_index()

print("Sentiment aggregation done")
print(news_df.head())
# Out:
# Error analyzing sentiment: 'float' object is not iterable
# Sentiment analysis done
#                                                Title       Date  \
# 0  Reliance Power share price update : Shareholdi... 2024-05-09
# 1  Reliance Power share price update : Shareholdi... 2024-05-09
# 2  Reliance Power share price update : Shareholdi... 2024-05-09
# 3  Reliance Power share price update : Shareholdi... 2024-05-09
# 4  Reliance Power share price update : Shareholdi... 2024-05-09
#
#                                              Content  Sentiment
# 0  Reliance Power has a 2.67% MF holding & 7.89% ...     0.0000
# 1  Reliance Power's Return on Equity (ROE) in the...     0.3400
# 2  Reliance Power has experienced a significant d...     0.8225
# 3  Today, Reliance Power's stock price dropped by...     0.7964
# 4  Reliance Power stock reached a low of₹24.55 an...    -0.1779
# Sentiment aggregation done
#         Date  Sentiment
# 0 2023-08-29   0.153205
# 1 2023-09-05   0.936000
# 2 2023-09-12        NaN
# 3 2023-09-19        NaN
# 4 2023-09-26        NaN

# %%
# Fetch stock data
current_date = datetime.today().strftime('%Y-%m-%d')
stock_df = yf.download('RPOWER.NS', start='2023-08-29', end=current_date, progress=False)
stock_df.reset_index(inplace=True)

print("Stock data fetched successfully")
print(stock_df.head())

columns_to_drop = ['Adj Close', 'Volume']
stock_df.drop(columns=columns_to_drop, inplace=True)

print("Columns dropped successfully")
print(stock_df.head())

# Calculate support and resistance
def calculate_support_resistance(data, window=20):
    data['Support'] = data['Low'].rolling(window=window).min()
    data['Resistance'] = data['High'].rolling(window=window).max()
    return data

stock_df = calculate_support_resistance(stock_df)
print("Support and resistance calculated")
print(stock_df.head())
# Out:
# Stock data fetched successfully
#         Date       Open   High    Low      Close  Adj Close     Volume
# 0 2023-08-29  17.650000  18.65  17.60  18.250000  18.250000  195394729
# 1 2023-08-30  18.500000  20.60  18.25  20.200001  20.200001  569141634
# 2 2023-08-31  20.400000  20.65  18.90  19.150000  19.150000  264116104
# 3 2023-09-01  19.299999  19.90  18.90  19.000000  19.000000  134930310
# 4 2023-09-04  19.299999  20.15  19.00  19.549999  19.549999  143886986
# Columns dropped successfully
#         Date       Open   High    Low      Close
# 0 2023-08-29  17.650000  18.65  17.60  18.250000
# 1 2023-08-30  18.500000  20.60  18.25  20.200001
# 2 2023-08-31  20.400000  20.65  18.90  19.150000
# 3 2023-09-01  19.299999  19.90  18.90  19.000000
# 4 2023-09-04  19.299999  20.15  19.00  19.549999
# Support and resistance calculated
#         Date       Open   High    Low      Close  Support  Resistance
# 0 2023-08-29  17.650000  18.65  17.60  18.250000      NaN         NaN
# 1 2023-08-30  18.500000  20.60  18.25  20.200001      NaN         NaN
# 2 2023-08-31  20.400000  20.65  18.90  19.150000      NaN         NaN
# 3 2023-09-01  19.299999  19.90  18.90  19.000000      NaN         NaN
# 4 2023-09-04  19.299999  20.15  19.00  19.549999      NaN         NaN

# %%
# Merge stock data with sentiment data
merged_df = pd.merge(stock_df, news_df[['Date', 'Sentiment']], on='Date', how='left')
merged_df['Sentiment'].fillna(method='ffill', inplace=True)

print("Merged dataframe created")
print(merged_df.head())
# Out:
# Merged dataframe created
#         Date       Open   High    Low      Close  Support  Resistance  \
# 0 2023-08-29  17.650000  18.65  17.60  18.250000      NaN         NaN
# 1 2023-08-30  18.500000  20.60  18.25  20.200001      NaN         NaN
# 2 2023-08-31  20.400000  20.65  18.90  19.150000      NaN         NaN
# 3 2023-09-01  19.299999  19.90  18.90  19.000000      NaN         NaN
# 4 2023-09-04  19.299999  20.15  19.00  19.549999      NaN         NaN
#
#    Sentiment
# 0   0.153205
# 1   0.153205
# 2   0.153205
# 3   0.153205
# 4   0.153205
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\2024439164.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Sentiment'].fillna(method='ffill', inplace=True)
# C:\Users\raghw\AppData\Local\Temp\ipykernel_30896\2024439164.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df['Sentiment'].fillna(method='ffill', inplace=True)

# %%
# Feature engineering
merged_df['Previous_Close'] = merged_df['Close'].shift(1)
merged_df['Price_Change'] = merged_df['Close'] - merged_df['Previous_Close']
merged_df.dropna(inplace=True)

features = merged_df[['Previous_Close', 'Sentiment', 'Support', 'Resistance']]
target = merged_df['Close']

print("Features and target defined")
print(features.head())
print(target.head())

# Save features and target to CSV
features.to_csv('features.csv', index=False)
target.to_csv('target.csv', index=False)
# Out:
# Features and target defined
#     Previous_Close  Sentiment    Support  Resistance
# 19       18.950001      0.936  17.600000   22.049999
# 20       19.000000      0.936  17.799999   22.049999
# 21       19.200001      0.936  17.799999   22.049999
# 22       19.150000      0.936  17.799999   22.049999
# 23       19.250000      0.936  17.799999   22.049999
# 19    19.000000
# 20    19.200001
# 21    19.150000
# 22    19.250000
# 23    19.250000
# Name: Close, dtype: float64

# %%
# Model training and evaluation
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

mlp_model = MLPRegressor(hidden_layer_sizes=(100,), activation='relu', solver='adam', max_iter=500, random_state=42)
mlp_model.fit(X_train, y_train)
print("Model training complete")

# Save the model
joblib.dump(mlp_model, 'mlp_modelRPOWER.pkl')

# Load the model
loaded_model = joblib.load('mlp_modelRPOWER.pkl')

# Predictions and evaluation
predictions = loaded_model.predict(X_test)

mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Model training complete
# Mean Squared Error (MSE): 4.8982175986216046
# Mean Absolute Error (MAE): 1.887014803041668
# R-squared (R²): 0.7389530142984571

# %%
# Future predictions
today = datetime.today().date()
next_seven_days_dates = [today + timedelta(days=i) for i in range(7)]

# Use the last 7 days of data as the starting point for predictions
last_7_days = merged_df.iloc[-7:][['Previous_Close', 'Sentiment', 'Support', 'Resistance']].values

predicted_close_prices = []
predicted_price_changes = []

for i in range(7):
    X_next_day = pd.DataFrame(last_7_days, columns=['Previous_Close', 'Sentiment', 'Support', 'Resistance'])
    next_day_close = mlp_model.predict(X_next_day.iloc[[-1]])[0]
    
    predicted_close_prices.append(next_day_close)
    
    price_change = next_day_close - last_7_days[-1][0]
    predicted_price_changes.append(price_change)

    last_7_days = np.append(last_7_days[1:], [[next_day_close, last_7_days[-1][1], last_7_days[-1][2], last_7_days[-1][3]]], axis=0)

predicted_df = pd.DataFrame({
    'Date': next_seven_days_dates,
    'Predicted_Close': predicted_close_prices,
    'Predicted_Price_Change': predicted_price_changes
})

predicted_df.to_csv('predicted_prices.csv', index=False)
print("Predicted prices saved to predicted_prices.csv")
# Out:
# Predicted prices saved to predicted_prices.csv

# %%
# Visualization
plt.figure(figsize=(10, 6))
plt.plot(news_df['Date'], news_df['Sentiment'], marker='o', linestyle='-')
plt.title('Sentiment Scores Over Time')
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

merged_df['Actual_Price_Change'] = merged_df['Close'] - merged_df['Previous_Close']
predicted_close_df = merged_df[['Date', 'Close']].copy()
predicted_close_df['Predicted_Close'] = mlp_model.predict(merged_df[['Previous_Close', 'Sentiment', 'Support', 'Resistance']])

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 14), sharex=True)

ax1.plot(merged_df['Date'], merged_df['Close'], label='Actual Close Price', color='blue')
ax1.plot(predicted_close_df['Date'], predicted_close_df['Predicted_Close'], label='Predicted Close Price', color='red', linestyle='--')
ax1.plot(predicted_df['Date'], predicted_df['Predicted_Close'], label='Next 7 Days Predicted Close Price', color='green', linestyle='--')
ax1.set_ylabel('Close Price')
ax1.set_title('Actual vs Predicted Close Price')
ax1.legend()

ax2.plot(merged_df['Date'], merged_df['Actual_Price_Change'], label='Actual Price Change', color='blue')
ax2.plot(predicted_df['Date'], predicted_df['Predicted_Price_Change'], label='Predicted Price Change', color='green', linestyle='--')
ax2.set_xlabel('Date')
ax2.set_ylabel('Price Change')
ax2.set_title('Actual vs Predicted Price Change')
ax2.legend()

plt.show()

# Save results
merged_df.to_csv('newsexperiment_try.csv', index=False)
print("Results saved to newsexperiment_try.csv")
# Out:
# Results saved to newsexperiment_try.csv
